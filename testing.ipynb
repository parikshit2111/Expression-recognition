# %%
import zipfile

zip_ref=zipfile.ZipFile('/content/zip')
zip_ref.extractall('./')
zip_ref.close()

# %%
# import os

# def delete_file(file_path):
#     try:
#         os.remove(file_path)
#     except FileNotFoundError:
#        pass
#     except PermissionError:
#         print(f"Error: Permission denied to delete '{file_path}'.")
#     except Exception as e:
#         print(f"Error: {e}")

# # Example usage
# for i in range(7000,7500):
#   i=str(i)
#   path='drive/MyDrive/._'+i+'.jpg'
#   delete_file(path)

# %%
# os.remove('drive/MyDrive/100.jpg')

# %%
import os
count=0
for i in range(0,3995):
  i=str(i)
  file_path = "drive/MyDrive/emotiondataset/train/Angry/"+i+".jpg"

  if os.path.exists(file_path):
    pass
  else:
    count=count+1

# %%
count
# Out:
# 0

# %%
import os
count=0
for i in range(0,436):
  i=str(i)
  file_path = "drive/MyDrive/emotiondataset/train/Disgust/"+i+".jpg"

  if os.path.exists(file_path):
    pass
  else:
    count=count+1

print(count)
# Out:
# 0

# %%
import os
count=0
for i in range(0,4097):
  i=str(i)
  file_path = "drive/MyDrive/emotiondataset/train/Fear/"+i+".jpg"

  if os.path.exists(file_path):
    pass
  else:
    count=count+1

print(count)
# Out:
# 0

# %%
import os
count=0
for i in range(0,7215):
  i=str(i)
  file_path = "drive/MyDrive/emotiondataset/train/Happy/"+i+".jpg"

  if os.path.exists(file_path):
    pass
  else:
    count=count+1

print(count)
# Out:
# 0

# %%
import os
count=0
for i in range(0,4965):
  i=str(i)
  file_path = "drive/MyDrive/emotiondataset/train/Neutral/"+i+".jpg"

  if os.path.exists(file_path):
    pass
  else:
    count=count+1

print(count)
# Out:
# 0

# %%
os.path.exists('drive/MyDrive/emotiondataset/train/Neutral/4.jpg')
# Out:
# True

# %%
import os
count=0
for i in range(0,4830):
  i=str(i)
  file_path = "drive/MyDrive/emotiondataset/train/Sad/"+i+".jpg"

  if os.path.exists(file_path):
    pass
  else:
    count=count+1

print(count)
# Out:
# 0

# %%
import os
count=0
for i in range(0,3171):
  i=str(i)
  file_path = "drive/MyDrive/emotiondataset/train/Surprise/"+i+".jpg"

  if os.path.exists(file_path):
    pass
  else:
    count=count+1

print(count)
# Out:
# 0
